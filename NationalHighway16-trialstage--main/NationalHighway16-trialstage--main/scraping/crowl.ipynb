# %%
import requests
from bs4 import BeautifulSoup

url = "https://www.city.kashiwa.lg.jp/dorokotsu/shiseijoho/keikaku/machizukuri/koutsuu/livecamera.html"

response = requests.get(url)

# Check if the request was successful
if response.status_code == 200:
    soup = BeautifulSoup(response.content, 'html.parser')
    print(soup.prettify())
else:
    print(f"Failed to fetch the webpage. Status code: {response.status_code}")
# Out:
# <!DOCTYPE html>
# <html lang="ja" xmlns:fb="http://www.facebook.com/2008/fbml" xmlns:og="http://ogp.me/ns#">
#  <head>
#   <meta charset="utf-8"/>
#   <title>
#    国道16号 ライブカメラ | 柏市役所
#   </title>
#   <meta content="国道16号 ライブカメラ" property="og:title"/>
#   <meta content="article" property="og:type"/>
#   <meta content="" property="og:description"/>
#   <meta content="https://www.city.kashiwa.lg.jp/dorokotsu/shiseijoho/keikaku/machizukuri/koutsuu/livecamera.html" property="og:url"/>
#   <meta content="https://www.city.kashiwa.lg.jp/shared/images/sns/logo.jpg" property="og:image"/>
#   <meta content="柏市" property="og:site_name"/>
#   <meta content="ja_JP" property="og:locale"/>
#   <meta content="4518" name="page_id"/>
#   <meta content="柏市" name="author"/>
#   <meta content="width=device-width, maximum-scale=3.0" name="viewport"/>
#   <meta content="telephone=no" name="format-detection"/>
#   <link href="/shared/style/default.css" media="all" rel="stylesheet"/>
#   <link href="/shared/style/layout.css" media="all" rel="stylesheet"/>
#   <link href="/shared/templates/free/style/edit.css" media="all" rel="stylesheet"/>
#   <link class="mc_css" href="/shared/style/smartphone.css" media="only screen and (max-width : 640px)" rel="stylesheet"/>
#   <link class="mc_css" href="/shared/templates/free/style/edit_sp.css" media="only screen and (max-width : 640px)" rel="stylesheet"/>
#   <link href="/shared/images/favicon/favicon.ico" rel="icon" type="image/vnd.microsoft.icon"/>
#   <link href="/shared/images/favicon/apple-touch-icon-precomposed.png" rel="apple-touch-icon-precomposed"/>
#   <script src="/shared/js/jquery.js">
#   </script>
#   <script src="/shared/js/setting.js">
#   </script>
#   <script src="/shared/js/page_print.js">
#   </script>
#   <script src="/shared/js/ga.js">
#   </script>
#   <script src="/shared/js/ga_social_tracking.js" type="text/javascript">
#   </script>
#   <script type="text/javascript">
#    var publish = true;
# var userAgent = window.navigator.userAgent.toLowerCase();
# var appVersion = window.navigator.appVersion.toLowerCase();
# if(userAgent.indexOf('msie') != -1){
#   if(appVersion.indexOf('msie 6.') != -1){
#     publish = false;
#   }else if(appVersion.indexOf('msie 7.') != -1){
#     publish = false;
#   }
# }
# if(publish){
# 	window.twttr = (function (d,s,id) {
# 	  var t, js, fjs = d.getElementsByTagName(s)[0];
# 	  if (d.getElementById(id)) return; js=d.createElement(s); js.id=id;
# 	  js.src='//platform.twitter.com/widgets.js'; fjs.parentNode.insertBefore(js, fjs);
# 	  return window.twttr || (t = { _e: [], ready: function(f){ t._e.push(f) } });
# 	}(document, 'script', 'twitter-wjs'));
# 	// Wait for the asynchronous resources to load
# 	twttr.ready(function(twttr) {
# 	    _ga.trackTwitter(); //Google Analytics tracking
# 	});
# }
#   </script>
#  </head>
#  <body class="format_free no_javascript cate003">
#   <div id="fb-root">
#   </div>
#   <script type="text/javascript">
#    var publish = true;
# var userAgent = window.navigator.userAgent.toLowerCase();
# var appVersion = window.navigator.appVersion.toLowerCase();
# if(userAgent.indexOf('msie') != -1){
#   if(appVersion.indexOf('msie 6.') != -1){
#     publish = false;
#   }else if(appVersion.indexOf('msie 7.') != -1){
#     publish = false;
#   }
# }
# if(publish){
# 	window.fbAsyncInit = function() {
# 	  _ga.trackFacebook(); //Google Analytics tracking
# 	};
# 	(function(d, s, id) {
# 	  var js, fjs = d.getElementsByTagName(s)[0];
# 	  if (d.getElementById(id)) return;
# 	  js = d.createElement(s); js.id = id;
# 	  js.src = "//connect.facebook.net/ja_JP/sdk.js#xfbml=1&version=v2.0";
# 	  fjs.parentNode.insertBefore(js, fjs);
# 	}(document, 'script', 'facebook-jssdk'));
# }
#   </script>
#   <script src="/shared/js/init.js">
#   </script>
#   <div id="tmp_wrapper">
#    <noscript>
#     <p>
#      このサイトではJavaScriptを使用したコンテンツ・機能を提供しています。JavaScriptを有効にするとご利用いただけます。
#     </p>
#    </noscript>
#    <p>
#     <a class="skip" href="#tmp_honbun">
#      本文へスキップします。
#     </a>
#    </p>
#    <header id="tmp_header">
#     <div class="container">
#      <div id="tmp_hlogo">
#       <p>
#        <a href="/index.html">
#         <span>
#          柏市
#         </span>
#        </a>
#       </p>
#      </div>
#      <div id="tmp_means">
#       <div id="tmp_setting_wrap">
#        <ul>
#         <li class="func_change">
#          <a href="/moji.html">
#           文字サイズ・色合い変更
#          </a>
#         </li>
#         <li class="func_language">
#          <a href="/foreignlanguage.html">
#           Foreign Language
#          </a>
#         </li>
#         <li class="func_access">
#          <a href="/facilities/cityhall/cityhall.html">
#           アクセス
#          </a>
#         </li>
#        </ul>
#       </div>
#       <div class="means_aside">
#        <div id="tmp_emergency">
#         <a class="emergency_ttl" href="/kinkyu/kinkyujoho.html">
#          緊急情報
#         </a>
#        </div>
#        <div id="tmp_safety">
#         <ul>
#          <li>
#           <a href="/anshinanzen/disaster/disaster_ready/bosaimap/index.html">
#            防災マップ
#           </a>
#          </li>
#          <li>
#           <a href="/hokennenkin/kyuubyou/kyubyo/index.html">
#            休日夜間・当番医
#           </a>
#          </li>
#         </ul>
#        </div>
#       </div>
#      </div>
#      <div class="emergency_info">
#       <div class="emergency_inner">
#        <div class="container">
#         <div class="emergency_list">
#         </div>
#        </div>
#       </div>
#      </div>
#      <ul id="tmp_hnavi_s">
#       <li id="tmp_hnavi_lmenu">
#        <a href="/kinkyu/kinkyujoho.html">
#         緊急情報
#        </a>
#       </li>
#       <li id="tmp_hnavi_rmenu">
#        <a href="javascript:void(0);">
#         閲覧支援
#        </a>
#       </li>
#       <li id="tmp_hnavi_access">
#        <a href="/facilities/cityhall/cityhall.html">
#         アクセス
#        </a>
#       </li>
#      </ul>
#     </div>
#    </header>
#    <div id="tmp_sma_menu">
#     <div class="wrap_sma_sch" id="tmp_sma_lmenu">
#      <div id="tmp_sma_emergency">
#      </div>
#      <p class="close_btn">
#       <a href="javascript:void(0);">
#        <span>
#         閉じる
#        </span>
#       </a>
#      </p>
#     </div>
#     <div class="wrap_sma_sch" id="tmp_sma_rmenu">
#      <div id="tmp_sma_func">
#      </div>
#      <p class="close_btn">
#       <a href="javascript:void(0);">
#        <span>
#         閉じる
#        </span>
#       </a>
#      </p>
#     </div>
#    </div>
#    <div class="sch_navi" id="navi_floating">
#     <div class="sch_navi_btn">
#      <div class="info_sch_menu_ttl">
#       <p>
#        <a class="close" href="javascript:void(0)">
#         情報検索メニュー
#         <span class="menu_navi">
#          開く
#         </span>
#        </a>
#       </p>
#      </div>
#      <div class="sch_navi_close">
#       <p>
#        <a href="javascript:void(0)">
#         閉じる
#        </a>
#       </p>
#      </div>
#     </div>
#     <div class="sch_navi_cnt">
#      <div class="sch_navi_block_link">
#       <div class="citizen_service_wrap menu_cate001">
#        <div class="service_head">
#         <p>
#          市民サービス
#         </p>
#        </div>
#        <div class="service_cnt">
#         <ul class="menu_list active">
#          <li>
#           <a href="/anshinanzen/index.html">
#            安心・安全
#           </a>
#          </li>
#          <li>
#           <a href="/haguhagu/index.html">
#            子育て
#           </a>
#          </li>
#          <li>
#           <a href="/kyouiku/index.html">
#            教育
#           </a>
#          </li>
#          <li>
#           <a href="/todokede/index.html">
#            届出・証明
#           </a>
#          </li>
#          <li>
#           <a href="/zeikin/index.html">
#            税金
#           </a>
#          </li>
#          <li>
#           <a href="/hokennenkin/index.html">
#            保険・年金・医療・健康
#           </a>
#          </li>
#          <li>
#           <a href="/kaigo/index.html">
#            介護・福祉・障害者
#           </a>
#          </li>
#          <li>
#           <a href="/garbage_environment/index.html">
#            ごみ
#           </a>
#          </li>
#          <li>
#           <a href="/living_environment/index.html">
#            生活・環境
#           </a>
#          </li>
#          <li>
#           <a href="/region/index.html">
#            地域・生涯学習・スポーツ
#           </a>
#          </li>
#          <li>
#           <a href="/about_kashiwa/culture/index.html">
#            歴史・文化・芸術
#           </a>
#          </li>
#         </ul>
#        </div>
#       </div>
#       <div class="sch_items_infor menu_cate001">
#        <ul>
#         <li>
#          <div class="items_wrap_cnt">
#           <div class="cnt_img">
#            <p>
#             <img alt="" height="50" src="/shared/templates/top/images/icon/sch_items_infor_1.png" width="45"/>
#            </p>
#           </div>
#           <div class="cnt_txt">
#            <p>
#             <a href="/koho/index.html">
#              広報・広聴
#             </a>
#            </p>
#           </div>
#          </div>
#         </li>
#         <li>
#          <div class="items_wrap_cnt">
#           <div class="cnt_img">
#            <p>
#             <img alt="" height="48" src="/shared/templates/top/images/icon/sch_items_infor_2.png" width="45"/>
#            </p>
#           </div>
#           <div class="cnt_txt">
#            <p>
#             <a href="/cgi-bin/event_cal_multi/calendar.cgi?type=2">
#              イベント情報
#             </a>
#            </p>
#           </div>
#          </div>
#         </li>
#         <li>
#          <div class="items_wrap_cnt">
#           <div class="cnt_img">
#            <p>
#             <img alt="" height="44" src="/shared/templates/top/images/icon/sch_items_infor_3.png" width="56"/>
#            </p>
#           </div>
#           <div class="cnt_ttl">
#            <p>
#             <a href="/facilities/index.html">
#              施設案内
#             </a>
#            </p>
#           </div>
#          </div>
#         </li>
#         <li>
#          <div class="items_wrap_cnt">
#           <div class="cnt_img">
#            <p>
#             <img alt="" height="48" src="/shared/templates/top/images/icon/sch_items_infor_4.png" width="50"/>
#            </p>
#           </div>
#           <div class="cnt_txt">
#            <p>
#             <a href="https://faq2.city.kashiwa.lg.jp/?site_domain=default" target="_blank">
#              よくある質問
#             </a>
#            </p>
#           </div>
#          </div>
#         </li>
#         <li>
#          <div class="items_wrap_cnt">
#           <div class="cnt_img">
#            <p>
#             <img alt="" height="57" src="/shared/templates/top/images/icon/sch_items_infor_5.png" width="58"/>
#            </p>
#           </div>
#           <div class="cnt_txt">
#            <p>
#             <a href="https://ttzk.graffer.jp/city-kashiwa" target="_blank">
#              手続きナビ
#             </a>
#            </p>
#           </div>
#          </div>
#         </li>
#        </ul>
#       </div>
#       <div class="gnavi_tab menu_cate001">
#        <ul>
#         <li>
#          <a class="color_blue" href="/jigyosha/index.html">
#           <span>
#            事業者サービス
#           </span>
#          </a>
#         </li>
#         <li>
#          <a class="color_purple" href="/shiseijoho/index.html">
#           <span>
#            市政情報
#           </span>
#          </a>
#         </li>
#        </ul>
#       </div>
#       <div class="citizen_service_wrap menu_cate002">
#        <div class="service_head">
#         <p>
#          事業者サービス
#         </p>
#        </div>
#        <div class="service_cnt">
#         <ul class="menu_list active">
#          <li>
#           <a href="/jigyosha/promotion/index.html">
#            経済・産業振興・農業
#           </a>
#          </li>
#          <li>
#           <a href="/jigyosha/labor/index.html">
#            仕事・雇用
#           </a>
#          </li>
#          <li>
#           <a href="/jigyosha/tender_contract/index.html">
#            入札・契約
#           </a>
#          </li>
#          <li>
#           <a href="/jigyosha/shiteikanri/index.html">
#            指定管理者制度
#           </a>
#          </li>
#          <li>
#           <a href="/jigyosha/finance/index.html">
#            融資・相談
#           </a>
#          </li>
#          <li>
#           <a href="/jigyosha/ad/index.html">
#            広告
#           </a>
#          </li>
#          <li>
#           <a href="/jigyosha/development/index.html">
#            開発・建築・道路
#           </a>
#          </li>
#          <li>
#           <a href="/jigyosha/environment/index.html">
#            環境・産業廃棄物
#           </a>
#          </li>
#          <li>
#           <a href="/jigyosha/zeikin/index.html">
#            税金
#           </a>
#          </li>
#          <li>
#           <a href="/jigyosha/gomi/index.html">
#            ごみ
#           </a>
#          </li>
#          <li>
#           <a href="/jigyosha/jousui/index.html">
#            上下水道
#           </a>
#          </li>
#          <li>
#           <a href="/jigyosha/welfare_sr/index.html">
#            高齢者福祉・介護保険
#           </a>
#          </li>
#          <li>
#           <a href="/jigyosha/welfare_hc/index.html">
#            障害福祉
#           </a>
#          </li>
#          <li>
#           <a href="/jigyosha/medical_hygiene/index.html">
#            医療・衛生
#           </a>
#          </li>
#          <li>
#           <a href="/jigyosha/inspection/index.html">
#            指導監査
#           </a>
#          </li>
#         </ul>
#        </div>
#       </div>
#       <div class="gnavi_tab menu_cate002">
#        <ul>
#         <li>
#          <a class="color_green" href="/index.html">
#           <span>
#            市民サービス
#           </span>
#          </a>
#         </li>
#         <li>
#          <a class="color_purple" href="/shiseijoho/index.html">
#           <span>
#            市政情報
#           </span>
#          </a>
#         </li>
#        </ul>
#       </div>
#       <div class="citizen_service_wrap menu_cate003">
#        <div class="service_head">
#         <p>
#          市政情報
#         </p>
#        </div>
#        <div class="service_cnt">
#         <ul class="menu_list active">
#          <li>
#           <a href="/shiseijoho/about_kashiwa/index.html">
#            市の情報
#           </a>
#          </li>
#          <li>
#           <a href="/shiseijoho/shisei/index.html">
#            市役所案内
#           </a>
#          </li>
#          <li>
#           <a href="/shiseijoho/gyouseikaikaku/index.html">
#            行政改革
#           </a>
#          </li>
#          <li>
#           <a href="/policy_pr/index.html">
#            行財政
#           </a>
#          </li>
#          <li>
#           <a href="/shiseijoho/shokuin/index.html">
#            職員
#           </a>
#          </li>
#          <li>
#           <a href="/shiseijoho/senkyo/index.html">
#            選挙
#           </a>
#          </li>
#          <li>
#           <a href="/shiseijoho/kokusaikouryu/index.html">
#            国際交流
#           </a>
#          </li>
#          <li>
#           <a href="/sankakueye/index.html">
#            男女共同参画
#           </a>
#          </li>
#          <li>
#           <a href="/shiseijoho/toukei/index.html">
#            統計
#           </a>
#          </li>
#          <li>
#           <a href="/shiseijoho/jouhoukoukai/index.html">
#            情報公開・個人情報
#           </a>
#          </li>
#          <li>
#           <a href="/shiseijoho/council/index.html">
#            附属機関等
#           </a>
#          </li>
#          <li>
#           <a href="/shiseijoho/keikaku/index.html">
#            計画・取組み
#           </a>
#          </li>
#          <li>
#           <a href="/shiseijoho/inspection/index.html">
#            監査
#           </a>
#          </li>
#          <li>
#           <a href="/assembly/index.html">
#            市議会
#           </a>
#          </li>
#          <li>
#           <a href="/kashiwa_boe/index.html">
#            教育委員会
#           </a>
#          </li>
#          <li>
#           <a href="/shiseijoho/e_service/index.html">
#            電子申請
#           </a>
#          </li>
#          <li>
#           <a href="/shiseijoho/forms/index.html">
#            申請書ダウンロード
#           </a>
#          </li>
#         </ul>
#        </div>
#       </div>
#       <div class="lists_cnt_icons menu_cate003">
#        <ul>
#         <li class="items_icon">
#          <div class="item_wrap" style="cursor: pointer;">
#           <div class="item_img">
#            <p>
#             <img alt="" src="/shared/templates/top/images/icon/icon_info_1.png"/>
#            </p>
#           </div>
#           <div class="item_txt">
#            <p>
#             <a href="/shiseijoho/shisei/soshiki/index.html">
#              組織一覧
#             </a>
#            </p>
#           </div>
#          </div>
#         </li>
#         <li class="items_icon">
#          <div class="item_wrap" style="cursor: pointer;">
#           <div class="item_img">
#            <p>
#             <img alt="" src="/shared/templates/top/images/icon/icon_info_2.png"/>
#            </p>
#           </div>
#           <div class="item_txt">
#            <p>
#             <a href="/shiseijoho/shokuin/recruit/index.html">
#              職員採用
#             </a>
#            </p>
#           </div>
#          </div>
#         </li>
#         <li class="items_icon">
#          <div class="item_wrap" style="cursor: pointer;">
#           <div class="item_img">
#            <p>
#             <img alt="" src="/shared/templates/top/images/icon/icon_info_3.png"/>
#            </p>
#           </div>
#           <div class="item_txt">
#            <p>
#             <a href="/shiseijoho/jouhoukoukai/opendate/index.html">
#              オープンデータ
#             </a>
#            </p>
#           </div>
#          </div>
#         </li>
#         <li class="items_icon">
#          <div class="item_wrap" style="cursor: pointer;">
#           <div class="item_img">
#            <p>
#             <img alt="" src="/shared/templates/top/images/icon/icon_info_4.png"/>
#            </p>
#           </div>
#           <div class="item_txt">
#            <p>
#             <a href="/koho/pressrelease/index.html">
#              報道資料
#             </a>
#            </p>
#           </div>
#          </div>
#         </li>
#         <li class="items_icon">
#          <div class="item_wrap" style="cursor: pointer;">
#           <div class="item_img">
#            <p>
#             <img alt="" src="/shared/templates/top/images/icon/icon_info_5.png"/>
#            </p>
#           </div>
#           <div class="item_txt">
#            <p>
#             <a href="/fdk/index.html">
#              消防局
#             </a>
#            </p>
#           </div>
#          </div>
#         </li>
#        </ul>
#       </div>
#       <div class="gnavi_tab menu_cate003">
#        <ul>
#         <li>
#          <a class="color_green" href="/index.html">
#           <span>
#            市民サービス
#           </span>
#          </a>
#         </li>
#         <li>
#          <a class="color_blue" href="/jigyosha/index.html">
#           <span>
#            事業者サービス
#           </span>
#          </a>
#         </li>
#        </ul>
#       </div>
#       <div id="tmp_sch_safety">
#        <ul>
#         <li>
#          <a href="/anshinanzen/disaster/disaster_ready/bosaimap/index.html">
#           <span>
#            防災マップ
#           </span>
#          </a>
#         </li>
#         <li>
#          <a href="/hokennenkin/kyuubyou/kyubyo/index.html">
#           <span>
#            休日夜間・当番医
#           </span>
#          </a>
#         </li>
#        </ul>
#       </div>
#      </div>
#     </div>
#    </div>
#    <div class="column_rnavi" id="tmp_wrap_main">
#     <div class="container">
#      <div id="tmp_directional">
#       <div id="tmp_pankuzu">
#        <p>
#         <a href="/shiseijoho/index.html">
#          ホーム
#         </a>
#         &gt;
#         <a href="/shiseijoho/keikaku/index.html">
#          計画・取組み
#         </a>
#         &gt;
#         <a href="/shiseijoho/keikaku/machizukuri/koutsuu/index.html">
#          交通
#         </a>
#         &gt; 国道16号 ライブカメラ
#        </p>
#       </div>
#       <div id="tmp_wrap_custom_update">
#        <div id="tmp_custom_update">
#         <p id="tmp_update">
#          <span>
#           更新日
#          </span>
#          2022年3月24日
#         </p>
#         <p id="tmp_pageid">
#          <span>
#           ページID
#          </span>
#          4518
#         </p>
#         <!--印刷ボタン-->
#         <p id="tmp_print">
#         </p>
#        </div>
#       </div>
#      </div>
#      <div id="tmp_main">
#       <div class="wrap_col_main">
#        <div class="col_main">
#         <p class="skip" id="tmp_honbun">
#          ここから本文です。
#         </p>
#         <div id="tmp_contents">
#          <h1>
#           国道16号 ライブカメラ
#          </h1>
#          <div class="article">
#           <p style="text-align: center;">
#            <img alt="" name="webcam" src="https://livecamera.city.kashiwa.lg.jp/-wvhttp-01-/image.cgi"/>
#            <script>
#             cam = new Image();
# 	cam.src = document.webcam.src;
# 	var count = 0;
# 	var countup = function(){
# 		console.log(count++);
# 		var now = new Date();
# 		document.webcam.src = cam.src + "?" + now.getTime();
# 	}
# var webcamTimer = setInterval(function(){
# 	 countup();
# if(count > 30){
# clearInterval(webcamTimer);
# }}, 1000);
#            </script>
#           </p>
#          </div>
#          <p>
#           <strong>
#            （注意）
#           </strong>
#          </p>
#          <p>
#           リアルタイムの映像です。ホームページの更新日の映像ではありません。
#          </p>
#          <p>
#           携帯端末の一部では映像がご覧いただけません。
#          </p>
#          <p>
#          </p>
#          <h2>
#           このカメラについて
#          </h2>
#          <ul>
#           <li>
#            <img alt="カメラ位置図説" class="float_rgt" height="321" src="/images/4518/002_png.gif" width="396"/>
#            カメラ設置場所は、柏市大井です。
#            <br/>
#            （右図参照）
#           </li>
#           <li>
#            表示までに多少時間がかかります。
#           </li>
#           <li>
#            左側が内回り（野田方向）右側が外回り（千葉方向）です。
#           </li>
#           <li>
#            1回にご覧になれる映像は1分までです。
#           </li>
#           <li>
#            雨天の際は見にくいことがあります。
#           </li>
#           <li>
#            時間帯によっては、つながりにくいことがあります。
#           </li>
#          </ul>
#          <h2>
#           こちらもご参照ください
#          </h2>
#          <p>
#           <a href="http://www.jartic.or.jp/">
#            財団法人日本道路交通情報センター（外部サイトへリンク）
#           </a>
#          </p>
#          <p>
#           上記ホームページアクセス後に「千葉県」→「千葉県西部」をクリックしてください。
#          </p>
#         </div>
#         <div id="tmp_social_plugins">
#          <div class="social_media_btn line_btn">
#           <script src="https://media.line.naver.jp/js/line-button.js" type="text/javascript">
#           </script>
#           <script type="text/javascript">
#            new jp.naver.line.media.LineButton({"pc":true,"lang":"ja","type":"a"});
#           </script>
#          </div>
#          <div class="social_media_btn facebook_btn">
#           <div class="fb-like" data-href="https://www.city.kashiwa.lg.jp/dorokotsu/shiseijoho/keikaku/machizukuri/koutsuu/livecamera.html" data-layout="button_count" data-send="false" data-show-faces="false" data-width="120">
#           </div>
#          </div>
#          <div class="social_media_btn twitter_btn">
#           <a class="twitter-share-button" data-lang="ja" data-text="国道16号 ライブカメラ" data-url="https://www.city.kashiwa.lg.jp/dorokotsu/shiseijoho/keikaku/machizukuri/koutsuu/livecamera.html" href="https://twitter.com/share">
#            ツイート
#           </a>
#           <script type="text/javascript">
#            if(publish){
# 	!function(d,s,id){var js,fjs=d.getElementsByTagName(s)[0],p=/^http:/.test(d.location)?'http':'https';if(!d.getElementById(id)){js=d.createElement(s);js.id=id;js.src=p+'://platform.twitter.com/widgets.js';fjs.parentNode.insertBefore(js,fjs);}}(document, 'script', 'twitter-wjs');
# }
#           </script>
#          </div>
#         </div>
#         <div id="tmp_inquiry">
#          <div id="tmp_inquiry_ttl">
#           <p>
#            お問い合わせ先
#           </p>
#          </div>
#          <div id="tmp_inquiry_cnt">
#           <div class="inquiry_parts">
#            <p>
#             所属課室：土木部交通政策課
#            </p>
#            <p>
#             柏市柏255番地（柏市役所分庁舎1-1階）
#            </p>
#            <p>
#             電話番号：04-7167-1219
#            </p>
#            <p>
#             ファックス番号：04-7160-1788
#            </p>
#            <p class="inquiry_btn">
#             <a href="https://secure.okbiz.jp/question-kashiwa/helpdesk?category_id=425&amp;site_domain=default" target="_blank">
#              お問い合わせフォーム
#             </a>
#            </p>
#           </div>
#          </div>
#         </div>
#         <div class="section_search">
#          <div class="search_ttl">
#           <p>
#            <span>
#             情報検索メニュー
#            </span>
#            このページに知りたい情報がない場合は
#           </p>
#          </div>
#          <div class="sch_menu_wrap">
#           <div class="site_search">
#            <div class="box_search">
#             <form action="/search_result.html" name="tmp_gsearch_form">
#              <div class="site_sch_box">
#               <div class="site_sch_ttl">
#                <p>
#                 <label for="tmp_site_query">
#                  サイト内検索
#                 </label>
#                </p>
#               </div>
#               <div class="site_wrap_sch">
#                <div class="site_sch_input">
#                 <p>
#                  <input id="tmp_site_query" name="q" size="31" type="text"/>
#                 </p>
#                 <p>
#                  <input id="tmp_site_sch_btn" name="sa" type="submit" value="検索"/>
#                 </p>
#                </div>
#                <div class="site_search_hidden">
#                 <p>
#                  <input name="cx" type="hidden" value="007625988971896691124:5kfgn5alv58"/>
#                  <input name="ie" type="hidden" value="UTF-8"/>
#                  <input name="cof" type="hidden" value="FORID:9"/>
#                 </p>
#                </div>
#               </div>
#              </div>
#             </form>
#            </div>
#            <div class="box_seach_link">
#             <p>
#              <a href="/kensakuhoho.html">
#               検索方法
#              </a>
#             </p>
#            </div>
#           </div>
#           <div class="info_sch_menu menu_cate001">
#            <div class="info_sch_menu_ttl">
#             <p>
#              市民サービス
#             </p>
#            </div>
#            <div class="info_sch_menu_cnt">
#             <ul class="info_sch_menu_list">
#              <li>
#               <a href="/anshinanzen/index.html">
#                安心・安全
#               </a>
#              </li>
#              <li>
#               <a href="/haguhagu/index.html">
#                子育て
#               </a>
#              </li>
#              <li>
#               <a href="/kyouiku/index.html">
#                教育
#               </a>
#              </li>
#              <li>
#               <a href="/todokede/index.html">
#                届出・証明
#               </a>
#              </li>
#              <li>
#               <a href="/zeikin/index.html">
#                税金
#               </a>
#              </li>
#              <li>
#               <a href="/hokennenkin/index.html">
#                保険・年金・医療・健康
#               </a>
#              </li>
#              <li>
#               <a href="/kaigo/index.html">
#                介護・福祉・障害者
#               </a>
#              </li>
#              <li>
#               <a href="/garbage_environment/index.html">
#                ごみ
#               </a>
#              </li>
#              <li>
#               <a href="/living_environment/index.html">
#                生活・環境
#               </a>
#              </li>
#              <li>
#               <a href="/region/index.html">
#                地域・生涯学習・スポーツ
#               </a>
#              </li>
#              <li>
#               <a href="/about_kashiwa/culture/index.html">
#                歴史・文化・芸術
#               </a>
#              </li>
#             </ul>
#            </div>
#           </div>
#           <div class="info_sch_menu menu_cate002">
#            <div class="info_sch_menu_ttl">
#             <p>
#              事業者サービス
#             </p>
#            </div>
#            <div class="info_sch_menu_cnt">
#             <ul class="info_sch_menu_list">
#              <li>
#               <a href="/jigyosha/promotion/index.html">
#                経済・産業振興・農業
#               </a>
#              </li>
#              <li>
#               <a href="/jigyosha/labor/index.html">
#                仕事・雇用
#               </a>
#              </li>
#              <li>
#               <a href="/jigyosha/tender_contract/index.html">
#                入札・契約
#               </a>
#              </li>
#              <li>
#               <a href="/jigyosha/shiteikanri/index.html">
#                指定管理者制度
#               </a>
#              </li>
#              <li>
#               <a href="/jigyosha/finance/index.html">
#                融資・相談
#               </a>
#              </li>
#              <li>
#               <a href="/jigyosha/ad/index.html">
#                広告
#               </a>
#              </li>
#              <li>
#               <a href="/jigyosha/development/index.html">
#                開発・建築・道路
#               </a>
#              </li>
#              <li>
#               <a href="/jigyosha/environment/index.html">
#                環境・産業廃棄物
#               </a>
#              </li>
#              <li>
#               <a href="/jigyosha/zeikin/index.html">
#                税金
#               </a>
#              </li>
#              <li>
#               <a href="/jigyosha/gomi/index.html">
#                ごみ
#               </a>
#              </li>
#              <li>
#               <a href="/jigyosha/jousui/index.html">
#                上下水道
#               </a>
#              </li>
#              <li>
#               <a href="/jigyosha/welfare_sr/index.html">
#                高齢者福祉・介護保険
#               </a>
#              </li>
#              <li>
#               <a href="/jigyosha/welfare_hc/index.html">
#                障害福祉
#               </a>
#              </li>
#              <li>
#               <a href="/jigyosha/medical_hygiene/index.html">
#                医療・衛生
#               </a>
#              </li>
#              <li>
#               <a href="/jigyosha/inspection/index.html">
#                指導監査
#               </a>
#              </li>
#             </ul>
#            </div>
#           </div>
#           <div class="info_sch_menu menu_cate003">
#            <div class="info_sch_menu_ttl">
#             <p>
#              市政情報
#             </p>
#            </div>
#            <div class="info_sch_menu_cnt">
#             <ul class="info_sch_menu_list">
#              <li>
#               <a href="/shiseijoho/about_kashiwa/index.html">
#                市の情報
#               </a>
#              </li>
#              <li>
#               <a href="/shiseijoho/shisei/index.html">
#                市役所案内
#               </a>
#              </li>
#              <li>
#               <a href="/shiseijoho/gyouseikaikaku/index.html">
#                行政改革
#               </a>
#              </li>
#              <li>
#               <a href="/policy_pr/index.html">
#                行財政
#               </a>
#              </li>
#              <li>
#               <a href="/shiseijoho/shokuin/index.html">
#                職員
#               </a>
#              </li>
#              <li>
#               <a href="/shiseijoho/senkyo/index.html">
#                選挙
#               </a>
#              </li>
#              <li>
#               <a href="/shiseijoho/kokusaikouryu/index.html">
#                国際交流
#               </a>
#              </li>
#              <li>
#               <a href="/sankakueye/index.html">
#                男女共同参画
#               </a>
#              </li>
#              <li>
#               <a href="/shiseijoho/toukei/index.html">
#                統計
#               </a>
#              </li>
#              <li>
#               <a href="/shiseijoho/jouhoukoukai/index.html">
#                情報公開・個人情報
#               </a>
#              </li>
#              <li>
#               <a href="/shiseijoho/council/index.html">
#                附属機関等
#               </a>
#              </li>
#              <li>
#               <a href="/shiseijoho/keikaku/index.html">
#                計画・取組み
#               </a>
#              </li>
#              <li>
#               <a href="/shiseijoho/inspection/index.html">
#                監査
#               </a>
#              </li>
#              <li>
#               <a href="/assembly/index.html">
#                市議会
#               </a>
#              </li>
#              <li>
#               <a href="/kashiwa_boe/index.html">
#                教育委員会
#               </a>
#              </li>
#              <li>
#               <a href="/shiseijoho/e_service/index.html">
#                電子申請
#               </a>
#              </li>
#              <li>
#               <a href="/shiseijoho/forms/index.html">
#                申請書ダウンロード
#               </a>
#              </li>
#             </ul>
#            </div>
#           </div>
#          </div>
#          <div class="info_media">
#           <ul>
#            <li class="info_media_koho">
#             <a href="/koho/index.html">
#              <span>
#               広報・広聴
#              </span>
#             </a>
#            </li>
#            <li class="info_media_event">
#             <a href="/cgi-bin/event_cal_multi/calendar.cgi?type=2">
#              <span>
#               イベント情報
#              </span>
#             </a>
#            </li>
#            <li class="info_media_shisetsu">
#             <a href="/facilities/index.html">
#              <span>
#               施設案内
#              </span>
#             </a>
#            </li>
#            <li class="info_media_faq">
#             <a href="https://faq2.city.kashiwa.lg.jp/?site_domain=default" target="_blank">
#              <span>
#               よくある質問
#              </span>
#             </a>
#            </li>
#           </ul>
#          </div>
#          <div class="sch_cat">
#           <div class="sch_cat_ttl">
#            <p>
#             他のサービス分類から探す
#            </p>
#           </div>
#           <div class="sch_cat_cnt">
#            <div class="sch_cat_lft">
#             <ul class="sch_cat_list">
#              <li class="sch_cat_1">
#               <a href="/index.html">
#                市民サービス
#               </a>
#              </li>
#              <li class="sch_cat_2">
#               <a href="/jigyosha/index.html">
#                事業者サービス
#               </a>
#              </li>
#              <li class="sch_cat_3">
#               <a href="/shiseijoho/index.html">
#                市政情報
#               </a>
#              </li>
#             </ul>
#            </div>
#            <div class="sch_cat_rgt">
#             <ul class="sch_cat_list">
#              <li class="sch_cat_4">
#               <a href="/shiseijoho/shisei/soshiki/index.html">
#                組織一覧
#               </a>
#              </li>
#             </ul>
#            </div>
#           </div>
#          </div>
#         </div>
#         <div id="tmp_feedback">
#          <div id="tmp_feedback_ttl">
#           <p>
#            より良いウェブサイトにするためにみなさまのご意見をお聞かせください
#           </p>
#          </div>
#          <div id="tmp_feedback_cnt">
#           <form action="/cgi-bin/feedback/feedback.cgi" id="feedback" method="post">
#            <p>
#             <input name="page_id" type="hidden" value="4518"/>
#             <input name="page_title" type="hidden" value="国道16号 ライブカメラ"/>
#             <input name="page_url" type="hidden" value="https://www.city.kashiwa.lg.jp/dorokotsu/shiseijoho/keikaku/machizukuri/koutsuu/livecamera.html"/>
#             <input name="item_cnt" type="hidden" value="2"/>
#            </p>
#            <fieldset>
#             <legend>
#              このページの情報は役に立ちましたか？
#             </legend>
#             <p>
#              <input id="que1_1" name="item_1" type="radio" value="役に立った"/>
#              <label for="que1_1">
#               1：役に立った
#              </label>
#             </p>
#             <p>
#              <input id="que1_2" name="item_1" type="radio" value="ふつう"/>
#              <label for="que1_2">
#               2：ふつう
#              </label>
#             </p>
#             <p>
#              <input id="que1_3" name="item_1" type="radio" value="役に立たなかった"/>
#              <label for="que1_3">
#               3：役に立たなかった
#              </label>
#             </p>
#            </fieldset>
#            <p>
#             <input name="label_1" type="hidden" value="質問：このページの情報は役に立ちましたか？"/>
#             <input name="nes_1" type="hidden" value="0"/>
#             <input name="img_1" type="hidden"/>
#             <input name="img_alt_1" type="hidden"/>
#             <input name="mail_1" type="hidden" value="0"/>
#            </p>
#            <fieldset>
#             <legend>
#              このページの情報は見つけやすかったですか？
#             </legend>
#             <p>
#              <input id="que2_1" name="item_2" type="radio" value="見つけやすかった"/>
#              <label for="que2_1">
#               1：見つけやすかった
#              </label>
#             </p>
#             <p>
#              <input id="que2_2" name="item_2" type="radio" value="ふつう"/>
#              <label for="que2_2">
#               2：ふつう
#              </label>
#             </p>
#             <p>
#              <input id="que2_3" name="item_2" type="radio" value="見つけにくかった"/>
#              <label for="que2_3">
#               3：見つけにくかった
#              </label>
#             </p>
#            </fieldset>
#            <p>
#             <input name="label_2" type="hidden" value="質問：このページの情報は見つけやすかったですか？"/>
#             <input name="nes_2" type="hidden" value="0"/>
#             <input name="img_2" type="hidden"/>
#             <input name="img_alt_2" type="hidden"/>
#             <input name="mail_2" type="hidden" value="0"/>
#            </p>
#            <p class="submit">
#             <input type="submit" value="送信"/>
#            </p>
#           </form>
#          </div>
#         </div>
#        </div>
#       </div>
#       <div class="wrap_col_rgt_navi">
#        <div class="col_rgt_navi">
#         <div id="tmp_publicity_s">
#          <script src="/shared/system/js/common/utility.js" type="text/javascript">
#          </script>
#          <script src="/shared/system/js/banner/banner_rand_prev.js" type="text/javascript">
#          </script>
#          <script type="text/javascript">
#           <!--
# document.write('<div id="advert_area_0" class="banner"></div>');
# var advert_0 = new KoukokuPublish();
# advert_0.LoadData(0,4);
# //-->
#          </script>
#          <noscript>
#           <p>
#            <a href="/banner/4/banner_list_4.html">
#             広告一覧ページへ
#            </a>
#           </p>
#          </noscript>
#         </div>
#         <div class="rnavi_func">
#          <div class="rnavi_func_ttl">
#           <p>
#            <a href="/shiseijoho/keikaku/machizukuri/koutsuu/index.html">
#             交通
#            </a>
#           </p>
#          </div>
#          <div class="rnavi_func_cnt">
#           <ul>
#            <li>
#             <a href="/dorokotsu/shiseijoho/keikaku/machizukuri/koutsuu/livecamera.html">
#              国道16号 ライブカメラ
#             </a>
#            </li>
#            <li>
#             <a href="/kotsuseisaku/shiseijoho/keikaku/machizukuri/koutsuu/4519.html">
#              社会資本総合整備計画（柏市総合交通戦略の推進）
#             </a>
#            </li>
#            <li>
#             <a href="/kotsuseisaku/shiseijoho/keikaku/machizukuri/koutsuu/6832.html">
#              平成23年度第1回柏市地域公共交通会議概要
#             </a>
#            </li>
#            <li>
#             <a href="/kotsuseisaku/shiseijoho/keikaku/machizukuri/koutsuu/6833.html">
#              平成24年度第1回柏市地域公共交通会議
#             </a>
#            </li>
#            <li>
#             <a href="/kotsuseisaku/shiseijoho/keikaku/machizukuri/koutsuu/6834.html">
#              平成24年度第2回柏市地域公共交通会議
#             </a>
#            </li>
#            <li>
#             <a href="/kotsuseisaku/shiseijoho/keikaku/machizukuri/koutsuu/6835.html">
#              柏市総合交通計画の中間評価と今後の施策の推進について
#             </a>
#            </li>
#            <li>
#             <a href="/kotsuseisaku/shiseijoho/keikaku/machizukuri/koutsuu/6838.html">
#              第3回柏市コミュニティバス運行調査検討会議概要
#             </a>
#            </li>
#            <li>
#             <a href="/kotsuseisaku/shiseijoho/keikaku/machizukuri/koutsuu/6837.html">
#              第2回柏市コミュニティバス運行調査検討会議概要
#             </a>
#            </li>
#            <li>
#             <a href="/kotsuseisaku/shiseijoho/keikaku/machizukuri/koutsuu/6836.html">
#              第1回柏市コミュニティバス運行調査検討会議概要
#             </a>
#            </li>
#            <li>
#             <a href="/kotsuseisaku/shiseijoho/keikaku/machizukuri/koutsuu/6840.html">
#              第3回柏市地域公共交通会議概要
#             </a>
#            </li>
#            <li>
#             <a href="/kotsuseisaku/shiseijoho/keikaku/machizukuri/koutsuu/6839.html">
#              第2回柏市地域公共交通会議概要
#             </a>
#            </li>
#            <li>
#             <a href="/kotsuseisaku/shiseijoho/keikaku/machizukuri/koutsuu/6841.html">
#              第1回柏市地域公共交通会議概要
#             </a>
#            </li>
#            <li>
#             <a href="/kotsuseisaku/r4syakoukinn.html">
#              社会資本総合整備計画（第二次柏市交通戦略の推進）
#             </a>
#            </li>
#           </ul>
#          </div>
#         </div>
#         <div id="box_article">
#          <div class="box_article_ttl">
#           <p>
#            こちらのページも読まれています
#           </p>
#          </div>
#          <div class="box_article_cnt">
#          </div>
#         </div>
#        </div>
#       </div>
#      </div>
#     </div>
#    </div>
#    <footer id="tmp_footer">
#     <div class="footer_inner">
#      <div class="pnavi">
#       <p class="ptop">
#        <a href="#tmp_header">
#         ページの先頭へ戻る
#        </a>
#       </p>
#      </div>
#      <div class="container">
#       <div class="footer_top">
#        <div class="footer_logo">
#         <p>
#          <span>
#           柏市役所
#          </span>
#         </p>
#        </div>
#        <div class="corporate_number">
#         <p>
#          法人番号：6000020122173
#         </p>
#        </div>
#       </div>
#       <div class="footer_cnt">
#        <address>
#         <p class="address_paragraph">
#          <span class="address_label">
#           〒277-8505
#          </span>
#          <span class="address_detail">
#           千葉県柏市柏5丁目10番1号
#           <a class="access_link" href="/facilities/cityhall/cityhall.html">
#            アクセス
#           </a>
#          </span>
#         </p>
#         <p>
#          <span class="address_label">
#           電話番号
#          </span>
#          <span class="address_detail">
#           ：04-7167-1111
#          </span>
#         </p>
#         <p>
#          <span class="address_label">
#           ファックス番号
#          </span>
#          <span class="address_detail">
#           ：04-7166-6026
#          </span>
#         </p>
#         <p>
#          <span class="address_label">
#           開庁時間
#          </span>
#          <span class="address_detail">
#           ：月曜日から金曜日の午前8時30分から午後5時15分
#          </span>
#         </p>
#         <p>
#          <span class="address_label">
#           閉庁日
#          </span>
#          <span class="address_detail">
#           ：祝日、休日、年末年始
#          </span>
#         </p>
#        </address>
#       </div>
#       <ul class="fnavi">
#        <li>
#         <a href="/riyoannai.html">
#          サイト利用案内
#         </a>
#        </li>
#        <li>
#         <a href="/kojinjoho.html">
#          個人情報保護方針
#         </a>
#        </li>
#        <li>
#         <a href="/sitemap.html">
#          サイトマップ
#         </a>
#        </li>
#        <li>
#         <a href="/otoiawase.html">
#          お問い合わせ
#         </a>
#        </li>
#       </ul>
#       <div class="kashiwa_location">
#        <p class="pc">
#         <img alt="Kashiwa City" height="300" src="/shared/images/footer/bg_location_footer.png" width="442"/>
#        </p>
#        <p class="sp">
#         <img alt="" height="457" src="/shared/images/footer/bg_location_footer_sp.png" width="640"/>
#        </p>
#       </div>
#      </div>
#     </div>
#     <div class="copyright_wrap">
#      <div class="container">
#       <p class="copyright" lang="en" xml:lang="en">
#        Copyright © Kashiwa City. All Rights Reserved.
#       </p>
#      </div>
#     </div>
#    </footer>
#   </div>
#   <script src="/shared/js/function.js">
#   </script>
#   <script src="/shared/js/main.js">
#   </script>
#   <script src="/shared/system/js/recommend/recommend.js">
#   </script>
#   <script async="" src="/_Incapsula_Resource?SWJIYLWA=719d34d31c8e3a6e6fffd425f7e032f3&amp;ns=1&amp;cb=1718290013" type="text/javascript">
#   </script>
#  </body>
# </html>
